# %%
import sympy as sy

# %%
x = sy.symbols('x')
x
# Out:
# x

# %%
type(x)
# Out:
# sympy.core.symbol.Symbol

# %%
f = 1/(1 + x**2)
f
# Out:
# 1/(x**2 + 1)

# %%
f.diff(x)
# Out:
# -2*x/(x**2 + 1)**2

# %%
sy.Integral(1/(1 + x**2), (x, 0, 1))
# Out:
# Integral(1/(x**2 + 1), (x, 0, 1))

# %%
sy.Integral(1/(1 + x**2), (x, 0, 1)).doit()
# Out:
# pi/4

# %%
sy.Integral(1/x, (x, 1, 10))
# Out:
# Integral(1/x, (x, 1, 10))

# %%
sy.Integral(1/x, (x, 1, 10)).doit()
# Out:
# log(10)

# %%
sy.oo
# Out:
# oo

# %%
sy.Integral(sy.exp(-x**2), (x, 0, sy.oo))
# Out:
# Integral(exp(-x**2), (x, 0, oo))

# %%
sy.Integral(sy.exp(-x**2), (x, 0, sy.oo)).doit()
# Out:
# sqrt(pi)/2

# %%
s = sy.symbols('s')

sy.laplace_transform(sy.exp(x), x, s)[0]
# Out:
# 1/(s - 1)
